# %%
import numpy as np
import pandas as pd
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90, 90, size = 2000)
longs = np.random.uniform(-90, 90, size = 2000)
lat_long = zip(lats, longs)
lat_long

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_long)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate [0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
#open weather url request
url = "http://api.openweathermap.org/data/2.5/weather?&units=imperial&appid="+ weather_api_key

# %%
#Create a empty list to hold weather data
cityData=[]

#Print the beginning of the loggin
print("Beginning Data Retrieval     ")
print("------------------------------")

#Create counters
recordCount = 1
setCount =1 

#Loop through all cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50
    if (i % 50 == 0 and i >= 50):
        setCount += 1
        recordCount = 1
    #create endpoint url with each city
    cityUrl = url + "&q=" + city.replace(" ", "+")
    
    #log the URL, record, and set numbers and the city
    print(f"Processing Record {recordCount} of Set {setCount} | {city}")
    recordCount += 1
    
#Run an API request for each city

    try:
        #Parse JSON and retrieve data
        cityWeather = requests.get(cityUrl).json()
        #Parse out needed data
        cityCountry = cityWeather["sys"]["country"]
        cityLat = cityWeather["coord"]["lat"]
        cityLong = cityWeather["coord"]["lon"]
        cityMaxTemp = cityWeather["main"]["temp_max"]
        cityHumidity = cityWeather["main"]["humidity"]
        cityClouds = cityWeather["clouds"]["all"]
        cityWind = cityWeather["wind"]["speed"]
        cityDescription = cityWeather["weather"][0]
        currentWeather = cityDescription["description"]
        #append city info into cityData list
        cityData.append({"City": city.title(),
                         "Country" : cityCountry,
                         "Lat":cityLat,
                         "Lng": cityLong,
                         "Max Temp": cityMaxTemp,
                         "Humidity": cityHumidity,
                         "Cloudiness": cityClouds,
                         "Wind Speed": cityWind,
                         "Current Description": currentWeather})

    #If an error occurs, skip city
    except:
        print("City not found. Skipping...")
        pass
    
#Indicate data loading is complete    
print("-----------------------")
print("Data Retrieval Complete")
print("-----------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | chuy
# Processing Record 2 of Set 1 | victoria
# Processing Record 3 of Set 1 | port elizabeth
# Processing Record 4 of Set 1 | odweyne
# Processing Record 5 of Set 1 | siedlce
# Processing Record 6 of Set 1 | bengkulu
# Processing Record 7 of Set 1 | rakke
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | manadhoo
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | sistranda
# Processing Record 13 of Set 1 | ilyich
# Processing Record 14 of Set 1 | jalu
# Processing Record 15 of Set 1 | miracema do tocantins
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | marawi
# Processing Record 18 of Set 1 | camacupa
# Processing Record 19 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 1 | upernavik
# Processing Record 21 of Set 1 | dikson
# Processing Record 22 of Set 1 | ribas do rio pardo
# Processing Record 23 of Set 1 | ilulissat
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | isiro
# Processing Record 26 of Set 1 | vila franca do campo
# Processing Record 27 of Set 1 | shakawe
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | bandarbeyla
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | nesna
# Processing Record 32 of Set 1 | inhambane
# Processing Record 33 of Set 1 | lebu
# Processing Record 34 of Set 1 | cabedelo
# Processing Record 35 of Set 1 | baherden
# Processing Record 36 of Set 1 | punjai puliyampatti
# Processing Record 37 of Set 1 | saint-philippe
# Processing Record 38 of Set 1 | taoudenni
# Processing Record 39 of Set 1 | falun
# Processing Record 40 of Set 1 | banepa
# Processing Record 41 of Set 1 | sur
# Processing Record 42 of Set 1 | cidreira
# Processing Record 43 of Set 1 | atar
# Processing Record 44 of Set 1 | buta
# Processing Record 45 of Set 1 | sao joao da barra
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | mikhaylovka
# Processing Record 48 of Set 1 | mahebourg
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | moultrie
# Processing Record 1 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 2 | nizwa
# Processing Record 3 of Set 2 | salalah
# Processing Record 4 of Set 2 | cockburn town
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | nuuk
# Processing Record 7 of Set 2 | bykovo
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | arraial do cabo
# Processing Record 10 of Set 2 | chapais
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | deda
# Processing Record 13 of Set 2 | east london
# Processing Record 14 of Set 2 | corralillo
# Processing Record 15 of Set 2 | kontagora
# Processing Record 16 of Set 2 | svencionys
# Processing Record 17 of Set 2 | port blair
# Processing Record 18 of Set 2 | olinda
# Processing Record 19 of Set 2 | palkino
# Processing Record 20 of Set 2 | mar del plata
# Processing Record 21 of Set 2 | gazanjyk
# Processing Record 22 of Set 2 | boke
# Processing Record 23 of Set 2 | manta
# Processing Record 24 of Set 2 | sambava
# Processing Record 25 of Set 2 | lixourion
# Processing Record 26 of Set 2 | souillac
# Processing Record 27 of Set 2 | tasiilaq
# Processing Record 28 of Set 2 | sarahan
# Processing Record 29 of Set 2 | bonavista
# Processing Record 30 of Set 2 | safwah
# City not found. Skipping...
# Processing Record 31 of Set 2 | changji
# Processing Record 32 of Set 2 | saint anthony
# Processing Record 33 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 2 | barra dos coqueiros
# Processing Record 35 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 2 | sicuani
# Processing Record 37 of Set 2 | hopewell
# Processing Record 38 of Set 2 | narsaq
# Processing Record 39 of Set 2 | lovozero
# Processing Record 40 of Set 2 | castro
# Processing Record 41 of Set 2 | bambous virieux
# Processing Record 42 of Set 2 | caravelas
# Processing Record 43 of Set 2 | coquimbo
# Processing Record 44 of Set 2 | oistins
# Processing Record 45 of Set 2 | baiao
# Processing Record 46 of Set 2 | marrakesh
# Processing Record 47 of Set 2 | saint george
# Processing Record 48 of Set 2 | san cristobal
# Processing Record 49 of Set 2 | goderich
# Processing Record 50 of Set 2 | camacha
# Processing Record 1 of Set 3 | beyneu
# Processing Record 2 of Set 3 | viedma
# Processing Record 3 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 3 | bandar-e anzali
# Processing Record 5 of Set 3 | goksun
# Processing Record 6 of Set 3 | talmenka
# Processing Record 7 of Set 3 | tazovskiy
# Processing Record 8 of Set 3 | puerto del rosario
# Processing Record 9 of Set 3 | moussoro
# Processing Record 10 of Set 3 | buraydah
# Processing Record 11 of Set 3 | madinat sittah uktubar
# Processing Record 12 of Set 3 | gafanha da encarnacao
# Processing Record 13 of Set 3 | arica
# Processing Record 14 of Set 3 | hamilton
# Processing Record 15 of Set 3 | teguldet
# Processing Record 16 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 3 | puerto leguizamo
# Processing Record 18 of Set 3 | iqaluit
# Processing Record 19 of Set 3 | torbay
# Processing Record 20 of Set 3 | vendychany
# Processing Record 21 of Set 3 | tessalit
# Processing Record 22 of Set 3 | henderson
# Processing Record 23 of Set 3 | negombo
# Processing Record 24 of Set 3 | nanortalik
# Processing Record 25 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 3 | longyearbyen
# Processing Record 27 of Set 3 | kirovskiy
# Processing Record 28 of Set 3 | zaidpur
# Processing Record 29 of Set 3 | aripuana
# Processing Record 30 of Set 3 | wanderlandia
# City not found. Skipping...
# Processing Record 31 of Set 3 | carpen
# Processing Record 32 of Set 3 | trinidad
# Processing Record 33 of Set 3 | faya
# Processing Record 34 of Set 3 | marquette
# Processing Record 35 of Set 3 | chamrajnagar
# Processing Record 36 of Set 3 | igrim
# Processing Record 37 of Set 3 | goundam
# Processing Record 38 of Set 3 | ajdabiya
# Processing Record 39 of Set 3 | clyde river
# Processing Record 40 of Set 3 | yining
# Processing Record 41 of Set 3 | marystown
# Processing Record 42 of Set 3 | marzuq
# Processing Record 43 of Set 3 | mehamn
# Processing Record 44 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 3 | niamey
# Processing Record 46 of Set 3 | kudahuvadhoo
# Processing Record 47 of Set 3 | vestmannaeyjar
# Processing Record 48 of Set 3 | port-gentil
# Processing Record 49 of Set 3 | coihaique
# Processing Record 50 of Set 3 | geraldton
# Processing Record 1 of Set 4 | resistencia
# Processing Record 2 of Set 4 | sao filipe
# Processing Record 3 of Set 4 | lodja
# Processing Record 4 of Set 4 | jorochito
# Processing Record 5 of Set 4 | ribeira grande
# Processing Record 6 of Set 4 | rawson
# Processing Record 7 of Set 4 | nouakchott
# Processing Record 8 of Set 4 | kuruman
# Processing Record 9 of Set 4 | saldanha
# Processing Record 10 of Set 4 | lagoa
# Processing Record 11 of Set 4 | kayerkan
# Processing Record 12 of Set 4 | beroroha
# Processing Record 13 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 15 of Set 4 | bealanana
# Processing Record 16 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 17 of Set 4 | crab hill
# City not found. Skipping...
# Processing Record 18 of Set 4 | ponta do sol
# Processing Record 19 of Set 4 | gat
# Processing Record 20 of Set 4 | kindia
# Processing Record 21 of Set 4 | svetlograd
# Processing Record 22 of Set 4 | solaro
# Processing Record 23 of Set 4 | noyabrsk
# Processing Record 24 of Set 4 | grand gaube
# Processing Record 25 of Set 4 | nathdwara
# Processing Record 26 of Set 4 | shostka
# Processing Record 27 of Set 4 | itupiranga
# Processing Record 28 of Set 4 | aktash
# Processing Record 29 of Set 4 | hawalli
# Processing Record 30 of Set 4 | yarada
# Processing Record 31 of Set 4 | pisco
# Processing Record 32 of Set 4 | oytal
# Processing Record 33 of Set 4 | san rafael
# Processing Record 34 of Set 4 | limburg
# Processing Record 35 of Set 4 | skjervoy
# Processing Record 36 of Set 4 | kopavogur
# Processing Record 37 of Set 4 | yar-sale
# Processing Record 38 of Set 4 | nantucket
# Processing Record 39 of Set 4 | altay
# Processing Record 40 of Set 4 | kruisfontein
# Processing Record 41 of Set 4 | carnarvon
# Processing Record 42 of Set 4 | oktyabrskoye
# Processing Record 43 of Set 4 | pafos
# Processing Record 44 of Set 4 | abu samrah
# Processing Record 45 of Set 4 | marv dasht
# City not found. Skipping...
# Processing Record 46 of Set 4 | vangaindrano
# Processing Record 47 of Set 4 | adrar
# Processing Record 48 of Set 4 | seda
# Processing Record 49 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 4 | necochea
# Processing Record 1 of Set 5 | klaksvik
# Processing Record 2 of Set 5 | mecca
# Processing Record 3 of Set 5 | acarau
# Processing Record 4 of Set 5 | pangnirtung
# Processing Record 5 of Set 5 | kambove
# Processing Record 6 of Set 5 | matay
# Processing Record 7 of Set 5 | kodino
# Processing Record 8 of Set 5 | peniche
# Processing Record 9 of Set 5 | kavaratti
# Processing Record 10 of Set 5 | axim
# Processing Record 11 of Set 5 | aden
# Processing Record 12 of Set 5 | rocha
# Processing Record 13 of Set 5 | melfi
# Processing Record 14 of Set 5 | muros
# Processing Record 15 of Set 5 | coihueco
# Processing Record 16 of Set 5 | virginia beach
# Processing Record 17 of Set 5 | skegness
# Processing Record 18 of Set 5 | burica
# City not found. Skipping...
# Processing Record 19 of Set 5 | henties bay
# Processing Record 20 of Set 5 | husavik
# Processing Record 21 of Set 5 | chokwe
# Processing Record 22 of Set 5 | temyasovo
# Processing Record 23 of Set 5 | boende
# Processing Record 24 of Set 5 | maniitsoq
# Processing Record 25 of Set 5 | limon
# Processing Record 26 of Set 5 | olafsvik
# Processing Record 27 of Set 5 | dzaoudzi
# Processing Record 28 of Set 5 | ampanihy
# Processing Record 29 of Set 5 | igarka
# Processing Record 30 of Set 5 | umm lajj
# Processing Record 31 of Set 5 | bathsheba
# Processing Record 32 of Set 5 | chotila
# Processing Record 33 of Set 5 | areia branca
# Processing Record 34 of Set 5 | mirabad
# Processing Record 35 of Set 5 | sedelnikovo
# City not found. Skipping...
# Processing Record 36 of Set 5 | balkhash
# Processing Record 37 of Set 5 | ayagoz
# Processing Record 38 of Set 5 | villa constitucion
# Processing Record 39 of Set 5 | tocopilla
# Processing Record 40 of Set 5 | bashtanka
# Processing Record 41 of Set 5 | diffa
# Processing Record 42 of Set 5 | netanya
# Processing Record 43 of Set 5 | hofn
# Processing Record 44 of Set 5 | manbij
# Processing Record 45 of Set 5 | saint-pierre
# Processing Record 46 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 47 of Set 5 | miraflores
# Processing Record 48 of Set 5 | challapata
# Processing Record 49 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 5 | the valley
# Processing Record 1 of Set 6 | kulhudhuffushi
# Processing Record 2 of Set 6 | codrington
# Processing Record 3 of Set 6 | mattawa
# Processing Record 4 of Set 6 | kattivakkam
# Processing Record 5 of Set 6 | sibiti
# Processing Record 6 of Set 6 | cuzama
# Processing Record 7 of Set 6 | umm jarr
# City not found. Skipping...
# Processing Record 8 of Set 6 | yurimaguas
# Processing Record 9 of Set 6 | hualmay
# Processing Record 10 of Set 6 | nikki
# Processing Record 11 of Set 6 | prainha
# Processing Record 12 of Set 6 | daman
# Processing Record 13 of Set 6 | kibre mengist
# Processing Record 14 of Set 6 | korla
# Processing Record 15 of Set 6 | conceicao do araguaia
# Processing Record 16 of Set 6 | burdur
# Processing Record 17 of Set 6 | ostrovnoy
# Processing Record 18 of Set 6 | varenikovskaya
# Processing Record 19 of Set 6 | jacareacanga
# Processing Record 20 of Set 6 | emba
# Processing Record 21 of Set 6 | leeuwarden
# Processing Record 22 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 23 of Set 6 | jumla
# Processing Record 24 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 6 | boa vista
# Processing Record 26 of Set 6 | kargopol
# Processing Record 27 of Set 6 | porbandar
# Processing Record 28 of Set 6 | snezhnogorsk
# Processing Record 29 of Set 6 | ulagan
# Processing Record 30 of Set 6 | varnamo
# Processing Record 31 of Set 6 | saint-augustin
# Processing Record 32 of Set 6 | mtambile
# Processing Record 33 of Set 6 | sisimiut
# Processing Record 34 of Set 6 | vardo
# Processing Record 35 of Set 6 | westerstede
# Processing Record 36 of Set 6 | riyadh
# Processing Record 37 of Set 6 | galgani
# City not found. Skipping...
# Processing Record 38 of Set 6 | sainte-suzanne
# Processing Record 39 of Set 6 | halifax
# Processing Record 40 of Set 6 | tarquinia
# Processing Record 41 of Set 6 | roald
# Processing Record 42 of Set 6 | alenquer
# Processing Record 43 of Set 6 | mezen
# Processing Record 44 of Set 6 | bagula
# Processing Record 45 of Set 6 | puerto baquerizo moreno
# Processing Record 46 of Set 6 | luderitz
# Processing Record 47 of Set 6 | awbari
# Processing Record 48 of Set 6 | qaqortoq
# Processing Record 49 of Set 6 | kidal
# Processing Record 50 of Set 6 | xuddur
# Processing Record 1 of Set 7 | havoysund
# Processing Record 2 of Set 7 | maragogi
# Processing Record 3 of Set 7 | dingle
# Processing Record 4 of Set 7 | castrovillari
# Processing Record 5 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 6 of Set 7 | anar darreh
# City not found. Skipping...
# Processing Record 7 of Set 7 | guadalajara
# Processing Record 8 of Set 7 | vilhena
# Processing Record 9 of Set 7 | mananjary
# Processing Record 10 of Set 7 | aracaju
# Processing Record 11 of Set 7 | monrovia
# Processing Record 12 of Set 7 | iralaya
# Processing Record 13 of Set 7 | raga
# Processing Record 14 of Set 7 | sayyan
# Processing Record 15 of Set 7 | borgarnes
# Processing Record 16 of Set 7 | cayenne
# Processing Record 17 of Set 7 | kangaatsiaq
# Processing Record 18 of Set 7 | samana
# Processing Record 19 of Set 7 | kasongo-lunda
# Processing Record 20 of Set 7 | navsari
# Processing Record 21 of Set 7 | srivardhan
# Processing Record 22 of Set 7 | biltine
# Processing Record 23 of Set 7 | mazara del vallo
# Processing Record 24 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 25 of Set 7 | berlevag
# Processing Record 26 of Set 7 | angola
# Processing Record 27 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 7 | nieuw nickerie
# Processing Record 29 of Set 7 | altamira
# Processing Record 30 of Set 7 | terrasini
# Processing Record 31 of Set 7 | cordoba
# Processing Record 32 of Set 7 | praia da vitoria
# Processing Record 33 of Set 7 | shar
# Processing Record 34 of Set 7 | aksu
# Processing Record 35 of Set 7 | ternovskaya
# Processing Record 36 of Set 7 | jacqueville
# Processing Record 37 of Set 7 | dzemul
# Processing Record 38 of Set 7 | margate
# Processing Record 39 of Set 7 | koungheul
# Processing Record 40 of Set 7 | abonnema
# Processing Record 41 of Set 7 | pindiga
# Processing Record 42 of Set 7 | mayor pablo lagerenza
# Processing Record 43 of Set 7 | sinop
# Processing Record 44 of Set 7 | vila velha
# Processing Record 45 of Set 7 | maku
# Processing Record 46 of Set 7 | lima
# Processing Record 47 of Set 7 | florida
# Processing Record 48 of Set 7 | la motte-servolex
# Processing Record 49 of Set 7 | kuryk
# Processing Record 50 of Set 7 | jiwani
# Processing Record 1 of Set 8 | dezful
# Processing Record 2 of Set 8 | dzilam gonzalez
# Processing Record 3 of Set 8 | grindavik
# Processing Record 4 of Set 8 | santa isabel do rio negro
# Processing Record 5 of Set 8 | tahoua
# Processing Record 6 of Set 8 | vila verde
# Processing Record 7 of Set 8 | horta
# Processing Record 8 of Set 8 | tulum
# Processing Record 9 of Set 8 | cobija
# Processing Record 10 of Set 8 | belyy yar
# Processing Record 11 of Set 8 | atasu
# Processing Record 12 of Set 8 | angra
# City not found. Skipping...
# Processing Record 13 of Set 8 | pauini
# Processing Record 14 of Set 8 | pimentel
# Processing Record 15 of Set 8 | castel volturno
# Processing Record 16 of Set 8 | diamantino
# Processing Record 17 of Set 8 | aswan
# Processing Record 18 of Set 8 | mattru
# Processing Record 19 of Set 8 | salekhard
# Processing Record 20 of Set 8 | road town
# Processing Record 21 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 8 | tromso
# Processing Record 23 of Set 8 | ous
# Processing Record 24 of Set 8 | kawambwa
# Processing Record 25 of Set 8 | kalmunai
# Processing Record 26 of Set 8 | rawah
# Processing Record 27 of Set 8 | paamiut
# Processing Record 28 of Set 8 | massaguet
# Processing Record 29 of Set 8 | yenagoa
# Processing Record 30 of Set 8 | bilma
# Processing Record 31 of Set 8 | porechye-rybnoye
# Processing Record 32 of Set 8 | mandali
# Processing Record 33 of Set 8 | parrita
# Processing Record 34 of Set 8 | laguna
# Processing Record 35 of Set 8 | murray
# Processing Record 36 of Set 8 | cheremshan
# Processing Record 37 of Set 8 | ormara
# Processing Record 38 of Set 8 | mantua
# Processing Record 39 of Set 8 | huarmey
# Processing Record 40 of Set 8 | teterow
# Processing Record 41 of Set 8 | pljevlja
# Processing Record 42 of Set 8 | gravdal
# Processing Record 43 of Set 8 | pokhara
# Processing Record 44 of Set 8 | marau
# Processing Record 45 of Set 8 | la asuncion
# Processing Record 46 of Set 8 | kushmurun
# Processing Record 47 of Set 8 | trelew
# Processing Record 48 of Set 8 | tinyahuarco
# Processing Record 49 of Set 8 | usinsk
# Processing Record 50 of Set 8 | tshikapa
# Processing Record 1 of Set 9 | walker
# Processing Record 2 of Set 9 | tsogni
# Processing Record 3 of Set 9 | bam
# Processing Record 4 of Set 9 | guatire
# Processing Record 5 of Set 9 | kurbnesh
# Processing Record 6 of Set 9 | sahrak
# City not found. Skipping...
# Processing Record 7 of Set 9 | praia
# Processing Record 8 of Set 9 | lasa
# Processing Record 9 of Set 9 | bocana de paiwas
# Processing Record 10 of Set 9 | trebisov
# Processing Record 11 of Set 9 | vestmanna
# Processing Record 12 of Set 9 | pointe michel
# Processing Record 13 of Set 9 | ushtobe
# Processing Record 14 of Set 9 | ayacucho
# Processing Record 15 of Set 9 | uppsala
# Processing Record 16 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 17 of Set 9 | hollins
# Processing Record 18 of Set 9 | liepaja
# Processing Record 19 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 20 of Set 9 | lincoln
# Processing Record 21 of Set 9 | takoradi
# Processing Record 22 of Set 9 | kaoma
# Processing Record 23 of Set 9 | kabalo
# Processing Record 24 of Set 9 | saint-georges
# Processing Record 25 of Set 9 | venezuela
# Processing Record 26 of Set 9 | richards bay
# Processing Record 27 of Set 9 | alta floresta
# Processing Record 28 of Set 9 | vagay
# Processing Record 29 of Set 9 | doliana
# Processing Record 30 of Set 9 | paysandu
# Processing Record 31 of Set 9 | kashi
# Processing Record 32 of Set 9 | senanga
# Processing Record 33 of Set 9 | neuquen
# Processing Record 34 of Set 9 | karoi
# Processing Record 35 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 9 | kalabo
# Processing Record 37 of Set 9 | sikasso
# Processing Record 38 of Set 9 | muravlenko
# Processing Record 39 of Set 9 | macara
# Processing Record 40 of Set 9 | vikulovo
# Processing Record 41 of Set 9 | conceicao do mato dentro
# Processing Record 42 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 9 | livramento
# Processing Record 44 of Set 9 | ibra
# Processing Record 45 of Set 9 | harlingen
# Processing Record 46 of Set 9 | inyonga
# Processing Record 47 of Set 9 | monduli
# Processing Record 48 of Set 9 | albemarle
# Processing Record 49 of Set 9 | carmelo
# Processing Record 50 of Set 9 | natal
# Processing Record 1 of Set 10 | lerwick
# Processing Record 2 of Set 10 | shubarkuduk
# Processing Record 3 of Set 10 | bara
# Processing Record 4 of Set 10 | padang
# Processing Record 5 of Set 10 | bagnols-sur-ceze
# Processing Record 6 of Set 10 | bursol
# City not found. Skipping...
# Processing Record 7 of Set 10 | abrau-dyurso
# Processing Record 8 of Set 10 | jaciara
# Processing Record 9 of Set 10 | beira
# Processing Record 10 of Set 10 | mangan
# Processing Record 11 of Set 10 | punta alta
# Processing Record 12 of Set 10 | ishimbay
# Processing Record 13 of Set 10 | santa helena de goias
# Processing Record 14 of Set 10 | san ramon
# Processing Record 15 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 16 of Set 10 | totma
# Processing Record 17 of Set 10 | pallasovka
# Processing Record 18 of Set 10 | lagunas
# Processing Record 19 of Set 10 | fredericton
# Processing Record 20 of Set 10 | valmiera
# Processing Record 21 of Set 10 | kanniyakumari
# Processing Record 22 of Set 10 | san matias
# Processing Record 23 of Set 10 | eyl
# Processing Record 24 of Set 10 | wiarton
# Processing Record 25 of Set 10 | finnsnes
# Processing Record 26 of Set 10 | saint-leu
# Processing Record 27 of Set 10 | tabou
# Processing Record 28 of Set 10 | keskin
# Processing Record 29 of Set 10 | aguas formosas
# Processing Record 30 of Set 10 | parrsboro
# Processing Record 31 of Set 10 | luena
# Processing Record 32 of Set 10 | olesnica
# Processing Record 33 of Set 10 | la baule-escoublac
# Processing Record 34 of Set 10 | chitral
# Processing Record 35 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 36 of Set 10 | chupa
# Processing Record 37 of Set 10 | uthal
# Processing Record 38 of Set 10 | puri
# Processing Record 39 of Set 10 | gamba
# Processing Record 40 of Set 10 | lago da pedra
# Processing Record 41 of Set 10 | manturovo
# Processing Record 42 of Set 10 | kakonko
# Processing Record 43 of Set 10 | znamenskoye
# Processing Record 44 of Set 10 | palma
# Processing Record 45 of Set 10 | mao
# Processing Record 46 of Set 10 | kumba
# Processing Record 47 of Set 10 | senneterre
# Processing Record 48 of Set 10 | san juan bautista
# Processing Record 49 of Set 10 | koslan
# Processing Record 50 of Set 10 | bilecik
# Processing Record 1 of Set 11 | kochubey
# Processing Record 2 of Set 11 | uyuni
# Processing Record 3 of Set 11 | dwarka
# Processing Record 4 of Set 11 | bonthe
# Processing Record 5 of Set 11 | opuwo
# Processing Record 6 of Set 11 | hwange
# Processing Record 7 of Set 11 | imbituba
# Processing Record 8 of Set 11 | chelno-vershiny
# Processing Record 9 of Set 11 | namanga
# Processing Record 10 of Set 11 | olenino
# Processing Record 11 of Set 11 | uray
# Processing Record 12 of Set 11 | balkanabat
# Processing Record 13 of Set 11 | mabaruma
# Processing Record 14 of Set 11 | ylojarvi
# Processing Record 15 of Set 11 | damietta
# Processing Record 16 of Set 11 | strezhevoy
# Processing Record 17 of Set 11 | loubomo
# Processing Record 18 of Set 11 | nioro
# Processing Record 19 of Set 11 | maxixe
# Processing Record 20 of Set 11 | namibe
# Processing Record 21 of Set 11 | llangefni
# Processing Record 22 of Set 11 | talnakh
# Processing Record 23 of Set 11 | makokou
# Processing Record 24 of Set 11 | ballitoville
# Processing Record 25 of Set 11 | villamontes
# Processing Record 26 of Set 11 | asilah
# Processing Record 27 of Set 11 | nurota
# Processing Record 28 of Set 11 | anuppur
# Processing Record 29 of Set 11 | trincomalee
# Processing Record 30 of Set 11 | campoverde
# Processing Record 31 of Set 11 | inta
# Processing Record 32 of Set 11 | dabakala
# Processing Record 33 of Set 11 | tutoia
# Processing Record 34 of Set 11 | kruszwica
# Processing Record 35 of Set 11 | akdepe
# Processing Record 36 of Set 11 | omboue
# Processing Record 37 of Set 11 | mahanoro
# Processing Record 38 of Set 11 | aleksandrov gay
# Processing Record 39 of Set 11 | westport
# Processing Record 40 of Set 11 | le port
# Processing Record 41 of Set 11 | cururupu
# Processing Record 42 of Set 11 | markala
# Processing Record 43 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 44 of Set 11 | saint-gilles
# Processing Record 45 of Set 11 | garbolovo
# Processing Record 46 of Set 11 | tafresh
# Processing Record 47 of Set 11 | tavricheskoye
# Processing Record 48 of Set 11 | boa viagem
# Processing Record 49 of Set 11 | diu
# Processing Record 50 of Set 11 | sarh
# Processing Record 1 of Set 12 | beloha
# Processing Record 2 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 3 of Set 12 | rodino
# Processing Record 4 of Set 12 | guane
# Processing Record 5 of Set 12 | novopokrovka
# Processing Record 6 of Set 12 | tekeli
# Processing Record 7 of Set 12 | uyemskiy
# Processing Record 8 of Set 12 | gazli
# Processing Record 9 of Set 12 | pallisa
# Processing Record 10 of Set 12 | lappersdorf
# Processing Record 11 of Set 12 | srisailam
# Processing Record 12 of Set 12 | novovoronezh
# Processing Record 13 of Set 12 | noeux-les-mines
# Processing Record 14 of Set 12 | shihezi
# Processing Record 15 of Set 12 | randolph
# Processing Record 16 of Set 12 | havelock
# Processing Record 17 of Set 12 | mvangue
# Processing Record 18 of Set 12 | adre
# Processing Record 19 of Set 12 | bulawayo
# Processing Record 20 of Set 12 | zambezi
# Processing Record 21 of Set 12 | cuamba
# Processing Record 22 of Set 12 | chlorakas
# Processing Record 23 of Set 12 | san borja
# Processing Record 24 of Set 12 | itarema
# Processing Record 25 of Set 12 | sorland
# Processing Record 26 of Set 12 | zhezkazgan
# Processing Record 27 of Set 12 | quatre cocos
# Processing Record 28 of Set 12 | ziway
# Processing Record 29 of Set 12 | pitimbu
# Processing Record 30 of Set 12 | paucartambo
# City not found. Skipping...
# Processing Record 31 of Set 12 | barranca
# Processing Record 32 of Set 12 | kamenka
# Processing Record 33 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 34 of Set 12 | mapiri
# Processing Record 35 of Set 12 | shonguy
# Processing Record 36 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 37 of Set 12 | skibbereen
# Processing Record 38 of Set 12 | mamallapuram
# Processing Record 39 of Set 12 | santa ana
# Processing Record 40 of Set 12 | los andes
# Processing Record 41 of Set 12 | rio verde de mato grosso
# Processing Record 42 of Set 12 | cartagena
# Processing Record 43 of Set 12 | aquiraz
# Processing Record 44 of Set 12 | coruripe
# Processing Record 45 of Set 12 | pombas
# Processing Record 46 of Set 12 | kautokeino
# Processing Record 47 of Set 12 | achisay
# City not found. Skipping...
# Processing Record 48 of Set 12 | marienburg
# Processing Record 49 of Set 12 | antofagasta
# Processing Record 50 of Set 12 | ayorou
# Processing Record 1 of Set 13 | conselheiro lafaiete
# Processing Record 2 of Set 13 | sura
# Processing Record 3 of Set 13 | ancud
# Processing Record 4 of Set 13 | boda
# Processing Record 5 of Set 13 | golkoy
# Processing Record 6 of Set 13 | oktyabrskiy
# Processing Record 7 of Set 13 | donskoye
# Processing Record 8 of Set 13 | ponta delgada
# Processing Record 9 of Set 13 | nuoro
# Processing Record 10 of Set 13 | bubaque
# Processing Record 11 of Set 13 | krasnoselkup
# Processing Record 12 of Set 13 | port hawkesbury
# Processing Record 13 of Set 13 | wadi musa
# Processing Record 14 of Set 13 | dawlatabad
# Processing Record 15 of Set 13 | touros
# Processing Record 16 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 17 of Set 13 | sao jose de piranhas
# Processing Record 18 of Set 13 | hemsedal
# Processing Record 19 of Set 13 | bajil
# Processing Record 20 of Set 13 | bababe
# City not found. Skipping...
# Processing Record 21 of Set 13 | vihti
# Processing Record 22 of Set 13 | gunjur
# Processing Record 23 of Set 13 | ballina
# Processing Record 24 of Set 13 | ilhabela
# Processing Record 25 of Set 13 | savalou
# Processing Record 26 of Set 13 | nalut
# Processing Record 27 of Set 13 | chapleau
# Processing Record 28 of Set 13 | nueva loja
# Processing Record 29 of Set 13 | turukhansk
# Processing Record 30 of Set 13 | port-cartier
# Processing Record 31 of Set 13 | menongue
# Processing Record 32 of Set 13 | monte gordo
# Processing Record 33 of Set 13 | zhanaozen
# Processing Record 34 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 35 of Set 13 | alberton
# Processing Record 36 of Set 13 | urumqi
# Processing Record 37 of Set 13 | tacuarembo
# Processing Record 38 of Set 13 | pankrushikha
# Processing Record 39 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 13 | watsa
# Processing Record 41 of Set 13 | hovin
# Processing Record 42 of Set 13 | karpathos
# Processing Record 43 of Set 13 | ornskoldsvik
# Processing Record 44 of Set 13 | koeru
# Processing Record 45 of Set 13 | beisfjord
# Processing Record 46 of Set 13 | malanje
# Processing Record 47 of Set 13 | shieli
# Processing Record 48 of Set 13 | dolores
# Processing Record 49 of Set 13 | kralupy nad vltavou
# Processing Record 50 of Set 13 | wattegama
# Processing Record 1 of Set 14 | thinadhoo
# Processing Record 2 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 14 | kemijarvi
# Processing Record 4 of Set 14 | svolvaer
# Processing Record 5 of Set 14 | barra do garcas
# Processing Record 6 of Set 14 | mosquera
# Processing Record 7 of Set 14 | salym
# Processing Record 8 of Set 14 | labelle
# Processing Record 9 of Set 14 | la union
# Processing Record 10 of Set 14 | black river
# Processing Record 11 of Set 14 | banjar
# Processing Record 12 of Set 14 | gogrial
# Processing Record 13 of Set 14 | pore
# Processing Record 14 of Set 14 | el balyana
# City not found. Skipping...
# Processing Record 15 of Set 14 | charyshskoye
# Processing Record 16 of Set 14 | razole
# Processing Record 17 of Set 14 | maloshuyka
# City not found. Skipping...
# Processing Record 18 of Set 14 | tambovka
# Processing Record 19 of Set 14 | svetlyy
# Processing Record 20 of Set 14 | concordia
# Processing Record 21 of Set 14 | turbat
# Processing Record 22 of Set 14 | springdale
# Processing Record 23 of Set 14 | nauta
# Processing Record 24 of Set 14 | saedinenie
# Processing Record 25 of Set 14 | turayf
# Processing Record 26 of Set 14 | buchanan
# Processing Record 27 of Set 14 | bjornevatn
# Processing Record 28 of Set 14 | abadan
# Processing Record 29 of Set 14 | kalengwa
# Processing Record 30 of Set 14 | glinka
# Processing Record 31 of Set 14 | chanika
# Processing Record 32 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 33 of Set 14 | barcelos
# Processing Record 34 of Set 14 | beni
# Processing Record 35 of Set 14 | osakarovka
# Processing Record 36 of Set 14 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 37 of Set 14 | ciudad bolivar
# Processing Record 38 of Set 14 | minchinabad
# Processing Record 39 of Set 14 | ugoofaaru
# Processing Record 40 of Set 14 | talara
# Processing Record 41 of Set 14 | nicoya
# Processing Record 42 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 43 of Set 14 | beberibe
# Processing Record 44 of Set 14 | trofors
# Processing Record 45 of Set 14 | nouadhibou
# Processing Record 46 of Set 14 | sao jose da coroa grande
# Processing Record 47 of Set 14 | matara
# Processing Record 48 of Set 14 | vallenar
# Processing Record 49 of Set 14 | miastko
# Processing Record 50 of Set 14 | sirjan
# Processing Record 1 of Set 15 | dortmund
# Processing Record 2 of Set 15 | hobyo
# Processing Record 3 of Set 15 | grande-riviere
# City not found. Skipping...
# Processing Record 4 of Set 15 | key largo
# Processing Record 5 of Set 15 | katete
# Processing Record 6 of Set 15 | uruacu
# Processing Record 7 of Set 15 | kaduqli
# Processing Record 8 of Set 15 | shelburne
# Processing Record 9 of Set 15 | uruzgan
# Processing Record 10 of Set 15 | icatu
# Processing Record 11 of Set 15 | maceio
# Processing Record 12 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 13 of Set 15 | sergeyevka
# Processing Record 14 of Set 15 | barra velha
# Processing Record 15 of Set 15 | farafangana
# Processing Record 16 of Set 15 | kansay
# City not found. Skipping...
# Processing Record 17 of Set 15 | lola
# Processing Record 18 of Set 15 | concepcion
# Processing Record 19 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 20 of Set 15 | umkomaas
# Processing Record 21 of Set 15 | mahibadhoo
# Processing Record 22 of Set 15 | ust-tsilma
# Processing Record 23 of Set 15 | birao
# Processing Record 24 of Set 15 | pontes e lacerda
# Processing Record 25 of Set 15 | aosta
# Processing Record 26 of Set 15 | neusiedl am see
# Processing Record 27 of Set 15 | saint-joseph
# Processing Record 28 of Set 15 | great yarmouth
# Processing Record 29 of Set 15 | paragominas
# Processing Record 30 of Set 15 | waw
# Processing Record 31 of Set 15 | azul
# Processing Record 32 of Set 15 | bonfim
# Processing Record 33 of Set 15 | karakendzha
# City not found. Skipping...
# Processing Record 34 of Set 15 | mumbwa
# Processing Record 35 of Set 15 | riberalta
# Processing Record 36 of Set 15 | velyka bilozerka
# Processing Record 37 of Set 15 | sackville
# Processing Record 38 of Set 15 | bethanien
# Processing Record 39 of Set 15 | tabriz
# Processing Record 40 of Set 15 | san andres
# Processing Record 41 of Set 15 | bulancak
# Processing Record 42 of Set 15 | ocean city
# Processing Record 43 of Set 15 | kiruna
# Processing Record 44 of Set 15 | gayny
# Processing Record 45 of Set 15 | iracoubo
# Processing Record 46 of Set 15 | taltal
# Processing Record 47 of Set 15 | najran
# Processing Record 48 of Set 15 | taywarah
# Processing Record 49 of Set 15 | umm bab
# Processing Record 50 of Set 15 | bouake
# Processing Record 1 of Set 16 | pastos bons
# Processing Record 2 of Set 16 | maldonado
# Processing Record 3 of Set 16 | mocuba
# Processing Record 4 of Set 16 | rafai
# Processing Record 5 of Set 16 | longlac
# City not found. Skipping...
# Processing Record 6 of Set 16 | porto novo
# Processing Record 7 of Set 16 | key west
# Processing Record 8 of Set 16 | dalbandin
# Processing Record 9 of Set 16 | lana
# Processing Record 10 of Set 16 | sardarshahr
# Processing Record 11 of Set 16 | grand-santi
# Processing Record 12 of Set 16 | bisert
# Processing Record 13 of Set 16 | hambantota
# -----------------------
# Data Retrieval Complete
# -----------------------

# %%
len(cityData)
# Out:
# 702

# %%
#Convert array to df
cityData_df = pd.DataFrame(cityData)
cityData_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Chuy      UY -33.6971  -53.4616     51.89        91          98
# 1        Victoria      HK  22.2855  114.1577     87.96        78          56
# 2  Port Elizabeth      ZA -33.9180   25.5701     75.09        64           0
# 3         Odweyne      SO   9.4092   45.0640     88.99        28          48
# 4         Siedlce      PL  52.1677   22.2901     74.89        43          11
# 5        Bengkulu      ID  -3.8004  102.2655     77.70        85          49
# 6           Rakke      EE  58.9817   26.2544     71.91        52          12
# 7       Cape Town      ZA -33.9258   18.4232     84.61        26           0
# 8        Manadhoo      MV   5.7667   73.3833     83.14        70          48
# 9         Qaanaaq      GL  77.4840  -69.3632     19.13        69         100
#
#    Wind Speed Current Description
# 0       13.65     overcast clouds
# 1        3.00       broken clouds
# 2       18.41           clear sky
# 3       19.13    scattered clouds
# 4        8.86          few clouds
# 5       10.09    scattered clouds
# 6       13.20          few clouds
# 7        6.91           clear sky
# 8        8.16    scattered clouds
# 9        7.11     overcast clouds

# %%
#Create output file
outputDataFile = "WeatherPy_Database.csv"
#Export cityData into a CSV
cityData_df.to_csv(outputDataFile)
